# %%
import pandas as pd
import matplotlib.pyplot as plt
import altair as alt
alt.renderers.enable('default')
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %%
data = pd.read_excel("base_de_dados.xlsx")

# %%
list(data)
# Out:
# ['Agencia',
#  'Exercicio_Apurado',
#  'Num_Processo',
#  'Ministerio',
#  'Tipo_Processo',
#  'Tipo_Alterado',
#  'Status_Processo',
#  'Data_Autuacao',
#  'Data_Encerramento',
#  'Relator',
#  'Quantidade_Relatores',
#  'Unidade_Tecnica_Responsavel',
#  'Unidade_Tecnica_Por_Agir',
#  'Confidencialidade',
#  'quant_responsaveis',
#  'decisao_normativa',
#  'instrucao_normativa',
#  'deliberacoes_quantidade',
#  'determinacoes',
#  'recomendacoes',
#  'sancoes',
#  'alerta']

# %%
data.head()
# Out:
#   Agencia  Exercicio_Apurado Num_Processo Ministerio  \
# 0       I             2010.0            1          a
# 1       I             2002.0            2          a
# 2       I             2004.0            3          a
# 3       I             2006.0            4          a
# 4       I             2009.0            5          a
#
#               Tipo_Processo Tipo_Alterado Status_Processo  Data_Autuacao  \
# 0  PC - Prestação de Contas           NÃO       Encerrado        40772.0
# 1  PC - Prestação de Contas           NÃO       Encerrado        37789.0
# 2  PC - Prestação de Contas           SIM       Encerrado        38512.0
# 3  PC - Prestação de Contas           NÃO       Encerrado        39269.0
# 4  PC - Prestação de Contas           NÃO       Encerrado        40386.0
#
#   Data_Encerramento Relator  Quantidade_Relatores Unidade_Tecnica_Responsavel  \
# 0             41603     ALC                   3.0                           A
# 1             38484      JN                   3.0                           B
# 2             39127      BZ                   1.0                           C
# 3             39968      WR                   2.0                           A
# 4             40612     ALC                   1.0                           B
#
#   Unidade_Tecnica_Por_Agir Confidencialidade  quant_responsaveis  \
# 0                        B          Restrito                   5
# 1                        A          Restrito                   5
# 2                        B          Restrito                   5
# 3                        A          Restrito                   5
# 4                        B          Restrito                   5
#
#   decisao_normativa                    instrucao_normativa  \
# 0       DN 2010-110               IN 2008-057; IN 2010-063
# 1               N/D  IN 2000-037; IN 2002-042; IN 2002-045
# 2       DN 2004-062               IN 2002-045; IN 2004-047
# 3       DN 2006-081                            IN 2004-047
# 4       DN 2009-102                            IN 2008-057
#
#    deliberacoes_quantidade determinacoes recomendacoes sancoes alerta
# 0                      1.0           Não           Sim     Não    Não
# 1                      1.0           Sim           Não     Não    Não
# 2                      1.0           Sim           Não     Não    Não
# 3                      1.0           Sim           Não     Não    Não
# 4                      1.0           Não           Sim     Não    Sim

# %% [markdown]
# ## 1. Qual a relação entre a quantidade de processos com
# ### a) A agência

# %%
agencias = pd.DataFrame(data.groupby("Agencia").count()["Exercicio_Apurado"])
agencias.columns = ["Quantidade"]
agencias.reset_index(level=0, inplace=True)
agencias
# Out:
#   Agencia  Quantidade
# 0       I          12
# 1      II           7
# 2     III          19
# 3      IV           5
# 4      IX          26
# 5       V          17
# 6      VI          17
# 7     VII          14
# 8    VIII          10

# %%
brush = alt.selection(type='interval', encodings=['x'])

bars = alt.Chart(width=300, height=400).mark_bar().encode(
    x='Agencia:O',
    y='mean(Quantidade):Q',
    opacity=alt.condition(brush, alt.OpacityValue(1), alt.OpacityValue(0.7))
).add_selection(
    brush
)

line = alt.Chart().mark_rule(color='firebrick').encode(
    y='mean(Quantidade):Q',
    size=alt.SizeValue(3)
).transform_filter(
    brush
)

alt.layer(bars, line, data=agencias)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %% [markdown]
# ### b) O ano

# %%
pd.options.display.float_format = '{:,.0f}'.format
anos = pd.DataFrame(data.groupby("Exercicio_Apurado").count()["Num_Processo"])
anos.reset_index(level=0, inplace=True)
anos.columns = ["Ano", "Quantidade"]
anos
# Out:
#      Ano  Quantidade
# 0  1,997           1
# 1  1,998           2
# 2  1,999           5
# 3  2,000           5
# 4  2,001           5
# 5  2,002           7
# 6  2,003           9
# 7  2,004           8
# 8  2,005           7
# 9  2,006           8
# 10 2,007          10
# 11 2,008          10
# 12 2,009           9
# 13 2,010          10
# 14 2,011           8
# 15 2,012           7
# 16 2,013           8
# 17 2,014           4
# 18 2,015           3
# 19 2,016           1

# %%
bars = alt.Chart(width=400, height=400).mark_bar().encode(
    x='Ano:O',
    y='mean(Quantidade):Q',
    opacity=alt.condition(brush, alt.OpacityValue(1), alt.OpacityValue(0.7))
).add_selection(
    brush
)

alt.layer(bars, line, data=anos)
# Out:
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %% [markdown]
# Este gráfico é interativo. Caso tenha problemas em interagir, clique [aqui](https://bit.ly/2HJ4Cto).

# %% [markdown]
# ### c) A agência em cada ano

# %%
pd.DataFrame(data.groupby(["Agencia", "Exercicio_Apurado"]).count()["Num_Processo"])
# Out:
#                            Num_Processo
# Agencia Exercicio_Apurado
# I       2,001                         1
#         2,002                         1
#         2,004                         1
#         2,006                         2
#         2,007                         2
#         2,008                         1
#         2,009                         1
#         2,010                         2
#         2,013                         1
# II      2,007                         1
#         2,008                         1
#         2,009                         1
#         2,010                         1
#         2,011                         1
#         2,012                         1
#         2,013                         1
# III     1,997                         1
#         1,998                         1
#         1,999                         1
#         2,000                         1
#         2,001                         1
#         2,002                         1
#         2,003                         1
#         2,004                         1
#         2,005                         1
#         2,006                         1
#         2,007                         1
#         2,008                         1
#         2,009                         1
#         2,010                         1
#         2,011                         1
#         2,012                         1
#         2,013                         1
#         2,014                         1
#         2,015                         1
# IV      2,005                         1
#         2,008                         1
#         2,009                         1
#         2,010                         1
#         2,014                         1
# IX      1,999                         1
#         2,000                         1
#         2,001                         1
#         2,002                         2
#         2,003                         2
#         2,004                         2
#         2,005                         2
#         2,006                         2
#         2,007                         2
#         2,008                         2
#         2,009                         2
#         2,010                         1
#         2,011                         2
#         2,012                         1
#         2,013                         2
#         2,015                         1
# V       1,998                         1
#         1,999                         1
#         2,000                         1
#         2,001                         1
#         2,002                         1
#         2,003                         2
#         2,004                         1
#         2,005                         1
#         2,006                         1
#         2,007                         1
#         2,008                         1
#         2,010                         1
#         2,011                         1
#         2,012                         1
#         2,013                         1
#         2,014                         1
# VI      1,999                         2
#         2,000                         1
#         2,001                         1
#         2,003                         2
#         2,004                         1
#         2,005                         1
#         2,006                         1
#         2,007                         1
#         2,008                         1
#         2,009                         1
#         2,010                         1
#         2,011                         1
#         2,012                         1
#         2,013                         1
#         2,015                         1
# VII     2,000                         1
#         2,002                         1
#         2,003                         1
#         2,004                         1
#         2,005                         1
#         2,006                         1
#         2,007                         1
#         2,008                         1
#         2,009                         1
#         2,010                         1
#         2,011                         1
#         2,012                         1
#         2,014                         1
#         2,016                         1
# VIII    2,002                         1
#         2,003                         1
#         2,004                         1
#         2,007                         1
#         2,008                         1
#         2,009                         1
#         2,010                         1
#         2,011                         1
#         2,012                         1
#         2,013                         1

# %% [markdown]
# ### d) O relator

# %%
pd.DataFrame(data.groupby("Relator").count()["Num_Processo"])
# Out:
#          Num_Processo
# Relator
#  JF                 1
# AA                  2
# AB                  5
# AC                  4
# AD                  1
# AI                  1
# ALC                 3
# AO                  2
# BO                  5
# BZ                 13
# GP                  1
# HC                  1
# IS                  1
# JF                 11
# JL                  8
# JN                  8
# JN                  1
# Jl                  1
# LR                  2
# M.V                 1
# MV                  3
# Mc                  1
# RS                 14
# UA                  5
# VF                  7
# VF1                 1
# WR                 24

# %% [markdown]
# ### e) A quantidade de relatores

# %%
qt_relatores = pd.DataFrame(data.groupby("Quantidade_Relatores").count()["Num_Processo"])
qt_relatores
# Out:
#                       Num_Processo
# Quantidade_Relatores
# 1                               69
# 2                               38
# 3                               10
# 4                                5
# 5                                2
# 7                                1
# 10                               1
# 13                               1

# %%
qt_relatores.plot()

# %% [markdown]
# ### f) A unidade técnica responsável

# %%
pd.DataFrame(data.groupby("Unidade_Tecnica_Responsavel").count()["Num_Processo"])
# Out:
#                              Num_Processo
# Unidade_Tecnica_Responsavel
# A                                      43
# B                                      42
# C                                      42

# %% [markdown]
# ## 2) Média de duração por agência e geral?

# %%
data["Data_Encerramento"] = data["Data_Encerramento"].replace(["N/D", "N/A"], pd.np.nan)
data2 = data.dropna()
data2["Duracao"] = data2["Data_Encerramento"]-data2["Data_Autuacao"]
duracao_agencia = pd.DataFrame(data2.groupby("Agencia").mean()["Duracao"])
duracao_agencia
# Out:
# C:\Users\vitoria\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#          Duracao
# Agencia
# I            616
# II           776
# III        1,118
# IV           908
# IX         1,223
# V            580
# VI         1,122
# VII          977
# VIII         243

# %%
duracao_agencia.reset_index(level=0, inplace=True)
duracao_agencia.columns = ["Agencia", "Duracao"]

# %%
bars = alt.Chart().mark_bar().encode(
    x='Agencia:O',
    y='mean(Duracao):Q',
    opacity=alt.condition(brush, alt.OpacityValue(1), alt.OpacityValue(0.7))
).add_selection(
    brush
)

line = alt.Chart().mark_rule(color='firebrick').encode(
    y='mean(Duracao):Q',
    size=alt.SizeValue(3)
).transform_filter(
    brush
)

print("Gráfico interativo")
alt.layer(bars, line, data=duracao_agencia)
# Out:
# Gráfico interativo
# <VegaLite 2 object>
#
# If you see this message, it means the renderer has not been properly enabled
# for the frontend that you are using. For more information, see
# https://altair-viz.github.io/user_guide/troubleshooting.html

# %% [markdown]
# ## 3) Qual a relação entre a quantidade de responsáveis com:
# ### a) A agência

# %%
pd.DataFrame(data.groupby(["quant_responsaveis", "Agencia"]).count()["Num_Processo"])
# Out:
#                             Num_Processo
# quant_responsaveis Agencia
# 5                  I                  12
#                    II                  7
#                    III                19
#                    IV                  5
#                    IX                 26
#                    V                  17
#                    VI                 17
#                    VII                14
#                    VIII               10

# %% [markdown]
# ### b) O ano e total

# %%
pd.DataFrame(data.groupby(["quant_responsaveis", "Exercicio_Apurado"]).count()["Num_Processo"])
# Out:
#                                       Num_Processo
# quant_responsaveis Exercicio_Apurado
# 5                  1,997                         1
#                    1,998                         2
#                    1,999                         5
#                    2,000                         5
#                    2,001                         5
#                    2,002                         7
#                    2,003                         9
#                    2,004                         8
#                    2,005                         7
#                    2,006                         8
#                    2,007                        10
#                    2,008                        10
#                    2,009                         9
#                    2,010                        10
#                    2,011                         8
#                    2,012                         7
#                    2,013                         8
#                    2,014                         4
#                    2,015                         3
#                    2,016                         1

# %% [markdown]
# ### c) O relator

# %%
pd.DataFrame(data.groupby(["quant_responsaveis", "Relator"]).count()["Num_Processo"])
# Out:
#                             Num_Processo
# quant_responsaveis Relator
# 5                   JF                 1
#                    AA                  2
#                    AB                  5
#                    AC                  4
#                    AD                  1
#                    AI                  1
#                    ALC                 3
#                    AO                  2
#                    BO                  5
#                    BZ                 13
#                    GP                  1
#                    HC                  1
#                    IS                  1
#                    JF                 11
#                    JL                  8
#                    JN                  8
#                    JN                  1
#                    Jl                  1
#                    LR                  2
#                    M.V                 1
#                    MV                  3
#                    Mc                  1
#                    RS                 14
#                    UA                  5
#                    VF                  7
#                    VF1                 1
#                    WR                 24

# %% [markdown]
# ### d) A unidade técnica responsável

# %%
pd.DataFrame(data.groupby(["quant_responsaveis", "Unidade_Tecnica_Responsavel"]).count()["Num_Processo"])
# Out:
#                                                 Num_Processo
# quant_responsaveis Unidade_Tecnica_Responsavel
# 5                  A                                      43
#                    B                                      42
#                    C                                      42

# %% [markdown]
# ### e) A unidade técnica por agir

# %%
pd.DataFrame(data.groupby(["quant_responsaveis", "Unidade_Tecnica_Por_Agir"]).count()["Num_Processo"])
# Out:
#                                              Num_Processo
# quant_responsaveis Unidade_Tecnica_Por_Agir
# 5                  A                                   63
#                    B                                   64

# %% [markdown]
# ## 4) Qual a relação entre a decisão normativa com

# %% [markdown]
# ### a) A agência

# %%
pd.DataFrame(data.groupby(["decisao_normativa", "Agencia"]).count()["Num_Processo"])
# Out:
#                            Num_Processo
# decisao_normativa Agencia
# DN 2004-062       I                   1
#                   III                 1
#                   IX                  2
#                   V                   1
#                   VI                  1
#                   VII                 1
#                   VIII                1
# DN 2005-71        III                 1
#                   IV                  1
#                   IX                  2
#                   V                   1
#                   VI                  1
#                   VII                 1
# DN 2006-081       I                   2
#                   III                 1
#                   IX                  2
#                   V                   1
#                   VI                  1
#                   VII                 1
# DN 2007-085       I                   2
#                   II                  1
#                   III                 1
#                   IX                  2
#                   V                   1
#                   VI                  1
#                   VII                 1
#                   VIII                1
# DN 2008-094       I                   1
#                   II                  1
#                   III                 1
#                   IV                  1
#                   IX                  2
#                   V                   1
#                   VI                  1
#                   VII                 1
#                   VIII                1
# DN 2009-102       I                   1
#                   II                  1
#                   III                 1
#                   IV                  1
#                   IX                  2
#                   VI                  1
#                   VII                 1
#                   VIII                1
# DN 2010-110       I                   2
#                   II                  1
#                   III                 1
#                   IV                  1
#                   IX                  1
#                   V                   1
#                   VI                  1
#                   VII                 1
#                   VIII                1
# DN 2011-117       II                  1
#                   III                 1
#                   IX                  2
#                   V                   1
#                   VI                  1
#                   VII                 1
#                   VIII                1
# DN 2012-124       II                  1
#                   III                 1
#                   IX                  1
#                   V                   1
#                   VI                  1
#                   VII                 1
#                   VIII                1
# DN 2013-132       I                   1
#                   II                  1
#                   III                 1
#                   IX                  2
#                   V                   1
#                   VI                  1
#                   VIII                1
# DN 2014-140       III                 1
#                   IV                  1
#                   V                   1
#                   VII                 1
# DN 2015-147       III                 1
#                   IX                  1
#                   VI                  1
# DN 2016-156       VII                 1
# N/D               I                   2
#                   III                 7
#                   IX                  7
#                   V                   7
#                   VI                  6
#                   VII                 3
#                   VIII                2

# %% [markdown]
# ### b) O ano e total

# %%
pd.DataFrame(data.groupby(["decisao_normativa", "Exercicio_Apurado"]).count()["Num_Processo"])
# Out:
#                                      Num_Processo
# decisao_normativa Exercicio_Apurado
# DN 2004-062       2,004                         8
# DN 2005-71        2,005                         7
# DN 2006-081       2,006                         8
# DN 2007-085       2,007                        10
# DN 2008-094       2,008                        10
# DN 2009-102       2,009                         9
# DN 2010-110       2,010                        10
# DN 2011-117       2,011                         8
# DN 2012-124       2,012                         7
# DN 2013-132       2,013                         8
# DN 2014-140       2,014                         4
# DN 2015-147       2,015                         3
# DN 2016-156       2,016                         1
# N/D               1,997                         1
#                   1,998                         2
#                   1,999                         5
#                   2,000                         5
#                   2,001                         5
#                   2,002                         7
#                   2,003                         9

# %% [markdown]
# ### c) O relator
